# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('000447_0.jpg',0)

# %%
print(img.shape)
# Out:
# (256, 192)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=192x256 at 0x7F6BBC18D950>

# %%
import numpy as np
sobel_2 = np.array([[-1,0,1], [-2,0,2],[-1,0,1]])

# %%
edge_sobel2 = np.zeros(img.shape)
for i in range(1,img.shape[0]-1):
  for j in range(1,img.shape[1]-1):
    mat = np.multiply(sobel_2,img[i-1:i+2,j-1:j+2]);
    edge_sobel2[i,j] = (abs(np.sum(mat)));

# %%
cv2_imshow(edge_sobel2)
# Out:
# <PIL.Image.Image image mode=L size=192x256 at 0x7F6BBC221190>
